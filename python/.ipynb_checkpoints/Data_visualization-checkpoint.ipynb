# %%
import pandas as pd
import os
from matplotlib import pyplot as plt
import numpy as np

# %%
directory = "../pfmdData/data_041522/"
z_gt = 1.875*100 # ground truth
# path = 'rotator_brightness_126.csv'

# %% [markdown]
# # Initialize and plot absolute error (From z_brightness_xxx)

# %%
# fig = plt.figure()
x_data = []
y_data = []
z_data = []
plt.figure(figsize=(10, 6), dpi=100)
labels = []
z_error_brightness = []
# plt.yscale('log')
for path in os.listdir(directory):
    legend = path[0:22] 
    labels.append(legend)
#     print(legend)
    curr = pd.read_csv(directory + path)
    # data points in all direction
    x = curr['x_cm']
    y = curr['y_cm']
    z = curr['z_cm']
    # errors
    z_error = abs(z - z_gt)
    # calculate rmse
    rmse = (((curr["z_cm"] - z_gt)**2).mean())**(1/2)
    # save data points in a list (data points are saved in this variable as list)
    x_data.append(x) 
    y_data.append(y) 
    z_data.append(z) 
    # plot
    z_error.plot(label = legend)
    z_error_brightness.append(z_error)


plt.legend()
plt.title("absolute error")
plt.ylabel("error (cm)")
plt.xlabel("sample")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# # Plot in 3D

# %%
# %matplotlib notebook

plt.figure(dpi=100)
ax = plt.axes(projection='3d')
for n in range(len(x_data)):
    ax.plot3D(x_data[n], z_data[n], y_data[n], linewidth=0.5)


# plt.legend()
plt.xlabel("x")
plt.ylabel("z")
plt.ylim(181,185)
# plt.zlabel("z")
plt.ioff()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Histogram for z error

# %% [markdown]
# ### individual histograms

# %%
track_num = len(x_data)
fig, axs = plt.subplots(track_num//2+1, 2, figsize=(6,10), dpi =100)
# set the spacing between subplots
fig.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.95, wspace=0.4, hspace=0.8)


for n in range(len(x_data)):

    error = z_data[n] - z_gt
    axs[n//2, n%2].hist(error)
    axs[n//2, n%2].set_title(str(n))
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### Stacked bar chart

# %%
track_num = len(x_data)
fig, ax = plt.subplots()
z_error_mean = []
z_error_std = []
new_labels = []
for n in range(len(x_data)):
    new_labels.append(labels[n][-3::])
    error = z_data[n] - z_gt
    z_error_mean.append(error.mean())
    z_error_std.append(error.std())
ax.boxplot(x_data, 0.3)
ax.set_xticklabels(new_labels)




fig.show()
# fig.legend()
# ax.set_ylabel('Scores')
# ax.set_title('Scores by group and gender')
# ax.legend()
# max,min,first quartile, median, third quartile
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Initialize and plot absolute error (From z_up_xxx)

# %%
directory = "../pfmdData/data_041922/"
z_gt = 2.26*100 # ground truth

# %%
# fig = plt.figure()
x_data = []
y_data = []
z_data = []
plt.figure(figsize=(10, 6), dpi=100)
labels = []
z_error_up = []
# plt.yscale('log')
for path in os.listdir(directory):
    legend = path[0:22] 
    labels.append(legend)
#     print(legend)
    curr = pd.read_csv(directory + path)
    # data points in all direction
    x = curr['x_cm']
    y = curr['y_cm']
    z = curr['z_cm']
    # errors
    z_error = abs(z - z_gt)
    # calculate rmse
    rmse = (((curr["z_cm"] - z_gt)**2).mean())**(1/2)
    # save data points in a list (data points are saved in this variable as list)
    x_data.append(x) 
    y_data.append(y) 
    z_data.append(z) 
    # plot
    z_error.plot(label = legend)
    z_error_up.append(z_error)


plt.legend()
plt.title("absolute error")
plt.ylabel("error (cm)")
plt.xlabel("sample")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib notebook

plt.figure(dpi=100)
ax = plt.axes(projection='3d')
for n in range(len(x_data)):
    ax.plot3D(x_data[n], z_data[n], y_data[n], linewidth=0.5)


# plt.legend()
plt.xlabel("x")
plt.ylabel("z")
plt.ylim(234,238)
# plt.zlabel("z")
plt.ioff()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
track_num = len(x_data)
fig, axs = plt.subplots(round(float(track_num)/2.0), 2, figsize=(6,10), dpi =100)
# set the spacing between subplots
fig.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.95, wspace=0.4, hspace=0.8)


for n in range(len(x_data)):

    error = z_data[n] - z_gt
    axs[n//2, n%2].hist(error)
    axs[n//2, n%2].set_title(str(n+1))
fig.show()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
track_num = len(x_data)
fig, ax = plt.subplots()
z_error_mean = []
z_error_std = []
new_labels = []
for n in range(len(x_data)):
    new_labels.append(labels[n][-3::])
    error = z_data[n] - z_gt
    z_error_mean.append(error.mean())
    z_error_std.append(error.std())
ax.boxplot(x_data, 0.3)
ax.set_xticklabels(new_labels)




fig.show()
# fig.legend()
# ax.set_ylabel('Scores')
# ax.set_title('Scores by group and gender')
# ax.legend()
# max,min,first quartile, median, third quartile
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Compare mean error z_brightness_xxx vs z_up_xxx

# %%
z_error_up
z_error_brightness
